# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/DEEPANSH/Desktop/analytics project/Dataset 4/Dataset 4.csv")
df
# Out:
#        Year  Primary [I - V] Male  Primary [I - V] Female  \
# 0   1950-51                   138                      54
# 1   1960-61                   236                     114
# 2   1970-71                   357                     213
# 3   1980-81                   453                     285
# 4   2000-01                   640                     498
# 5   2005-06                   705                     616
# 6   2006-07                   711                     626
# 7   2007-08                   711                     644
# 8   2008-09                   706                     647
# 9   2009-10                   697                     639
# 10  2010-11                   701                     646
# 11  2011-12                   726                     672
# 12  2012-13                   696                     652
# 13  2013-14                   686                     638
# 14  2014-15                   676                     629
# ...

# %%
Secondary_total = df.iloc[:, 9].values
Secondary_total
# Out:
# array([ nan,  nan,  nan,  nan, 190., 250., 259., 282., 295., 307., 318.,
#        341., 346., 373., 383., 391.])

# %%
plt.figure(figsize=[10,6])
x = np.array([2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])
y1 = np.array([705, 711, 711, 706, 697, 701, 726, 696,
       686, 676, 669])
y2 =np.array([ 616, 626, 644, 647, 639, 646, 672, 652,
       638, 629, 622])
y3 = np.array([ 1321, 1337, 1355, 1353, 1336, 1347,
       1398, 1348, 1324, 1305, 1291])

plt.plot(x, y1, label = "Primary [I - V] Male",linestyle='--', marker='o', c = "r")
plt.plot(x, y2, label = "Primary [I - V] Female",linestyle='--', marker='o', c = "b")
plt.plot(x, y3, label = "Primary [I - V] Total",linestyle='--', marker='o', c = "g")

m1, b1 = np.polyfit(x, y1, 1)
print('Primary male m = ',m1,'b=',b1)

plt.plot(x, m1*x + b1,label = "Reg line Primary Male", c = "black",linewidth=3.0)
print(m1*x + b1,'\n')

m2, b2 = np.polyfit(x, y2, 1)
print('Primary female m = ',m2,'b=',b2)

plt.plot(x, m2*x + b2,label = "Reg line Primary Female", c = "black",linewidth=3.0)
print(m2*x + b2)

plt.xlabel('Years')
plt.ylabel('No of students')
plt.title('Line plot of Primary Students vs Year')
plt.legend()

plt.show()
# Out:
# Primary male m =  -3.50909090909109 b= 7751.818181818545
# [716.09090909 712.58181818 709.07272727 705.56363636 702.05454545
#  698.54545455 695.03636364 691.52727273 688.01818182 684.50909091
#  681.        ]
#
# Primary female m =  0.6090909090908436 b= -585.0909090907775
# [636.13636364 636.74545455 637.35454545 637.96363636 638.57272727
#  639.18181818 639.79090909 640.4        641.00909091 641.61818182
#  642.22727273]

# %%
from sklearn.metrics import r2_score 
f1 = [716.09090909, 712.58181818, 709.07272727, 705.56363636, 702.05454545,
 698.54545455, 695.03636364, 691.52727273, 688.01818182, 684.50909091,
 681.]

f2 = [636.13636364, 636.74545455, 637.35454545, 637.96363636, 638.57272727,
 639.18181818, 639.79090909, 640.4, 641.00909091, 641.61818182,
 642.22727273]

r2_1 = r2_score(y1, f1 ) 
r2_2 = r2_score(y2, f2 ) 

print('r2 score of linear model wrt primary male is      ', r2_1)
print('r2 score of linear model wrt primary female is    ', r2_2)
# Out:
# r2 score of linear model wrt primary male is       0.49894849653003814
# r2 score of linear model wrt primary female is     0.016431185695681583

# %%
def primary_male(x):
 y = -3.50909090909109*x + 7751.818181818545
 return y

def primary_female(x):
 y = 0.6090909090908436*x -585.0909090907775
 return y

print('primary male 2016 pred',primary_male(2016))
print('primary female 2016 pred',primary_female(2016))
print('primary total 2016 pred',primary_male(2016)+primary_female(2016),'\n')

print('primary male 2017 pred',primary_male(2017))
print('primary female 2017 pred',primary_female(2017))
print('primary total 2017 pred',primary_male(2017)+primary_female(2017),'\n')
# Out:
# primary male 2016 pred 677.4909090909077
# primary female 2016 pred 642.8363636363632
# primary total 2016 pred 1320.327272727271
#
# primary male 2017 pred 673.9818181818164
# primary female 2017 pred 643.445454545454
# primary total 2017 pred 1317.4272727272705

# %%
plt.figure(figsize=[10,6])
x = np.array([2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])
y1 = np.array([289, 299, 311, 314, 317, 327, 331, 333,
       341, 345, 347])
y2 =np.array([233, 246, 262, 270, 278, 292, 299, 317,
       323, 327, 329])
y3 = np.array([522, 545, 573, 584, 595, 619, 630, 650,
       664, 672, 676])

plt.plot(x, y1, label = "Upper Primary [VI- VII] Male",linestyle='--', marker='o', c = "r")
plt.plot(x, y2, label = "Upper Primary [VI- VII] Female",linestyle='--', marker='o', c = "b")
plt.plot(x, y3, label = "Upper Primary [VI- VII] Total",linestyle='--', marker='o', c = "g")

m1, b1 = np.polyfit(x, y1, 1)
print('Upper Primary male m = ',m1,'b=',b1)

plt.plot(x, m1*x + b1,label = "Reg line Upper Primary Male", c = "black",linewidth=3.0)
print(m1*x + b1,'\n')

m2, b2 = np.polyfit(x, y2, 1)
print('Upper Primary female m = ',m2,'b=',b2)

plt.plot(x, m2*x + b2,label = "Reg line Upper Primary Female", c = "black",linewidth=3.0)
print(m2*x + b2)

plt.xlabel('Years')
plt.ylabel('No of students')
plt.title('Line plot of Upper Primary Students vs Year')
plt.legend()

plt.show()
# Out:
# Upper Primary male m =  5.600000000000228 b= -10932.909090909547
# [295.09090909 300.69090909 306.29090909 311.89090909 317.49090909
#  323.09090909 328.69090909 334.29090909 339.89090909 345.49090909
#  351.09090909]
#
# Upper Primary female m =  10.018181818182262 b= -19847.81818181908
# [238.63636364 248.65454545 258.67272727 268.69090909 278.70909091
#  288.72727273 298.74545455 308.76363636 318.78181818 328.8
#  338.81818182]

# %%
from sklearn.metrics import r2_score 
f1 = [295.09090909, 300.69090909, 306.29090909, 311.89090909, 317.49090909,
 323.09090909, 328.69090909, 334.29090909, 339.89090909, 345.49090909,
 351.09090909]

f2 = [238.63636364, 248.65454545, 258.67272727, 268.69090909, 278.70909091,
 288.72727273, 298.74545455, 308.76363636, 318.78181818, 328.8,
 338.81818182]

r2_1 = r2_score(y1, f1 ) 
r2_2 = r2_score(y2, f2 ) 

print('r2 score of linear model wrt upper primary male is      ', r2_1)
print('r2 score of linear model wrt upper primary female is    ', r2_2)
# Out:
# r2 score of linear model wrt upper primary male is       0.9698308030465674
# r2 score of linear model wrt upper primary female is     0.9780172344251913

# %%
def upper_primary_male(x):
 y = 5.600000000000228*x -10932.909090909547
 return y

def upper_primary_female(x):
 y = 10.018181818182262*x -19847.81818181908
 return y

print('upper primary male 2016 pred',upper_primary_male(2016))
print('upper primary female 2016 pred',upper_primary_female(2016))
print('upper primary total 2016 pred',upper_primary_male(2016)+upper_primary_female(2016),'\n')

print('upper primary male 2017 pred',upper_primary_male(2017))
print('upper primary female 2017 pred',upper_primary_female(2017))
print('upper primary total 2017 pred',upper_primary_male(2017)+upper_primary_female(2017),'\n')
# Out:
# upper primary male 2016 pred 356.6909090909121
# upper primary female 2016 pred 348.83636363636106
# upper primary total 2016 pred 705.5272727272732
#
# upper primary male 2017 pred 362.29090909091246
# upper primary female 2017 pred 358.85454545454195
# upper primary total 2017 pred 721.1454545454544

# %%
plt.figure(figsize=[10,6])
x = np.array([2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])
y1 = np.array([145., 149., 159., 165., 169., 175.,
       186., 183., 197., 201., 205.])
y2 =np.array([105., 110., 123., 130., 138., 143.,
       155., 163., 176., 182., 186.])
y3 = np.array([250., 259., 282., 295., 307., 318.,
       341., 346., 373., 383., 391.])

plt.plot(x, y1, label = "Secondary [IX - XII] Male",linestyle='--', marker='o', c = "r")
plt.plot(x, y2, label = "Secondary [IX - XII] Female",linestyle='--', marker='o', c = "b")
plt.plot(x, y3, label = "Secondary [IX - XII] Total",linestyle='--', marker='o', c = "g")

m1, b1 = np.polyfit(x, y1, 1)
print('Secondary male m = ',m1,'b=',b1)

plt.plot(x, m1*x + b1,label = "Reg line Upper Secondary Male", c = "black",linewidth=3.0)
print(m1*x + b1,'\n')

m2, b2 = np.polyfit(x, y2, 1)
print('Secondary female m = ',m2,'b=',b2)

plt.plot(x, m2*x + b2,label = "Reg line Upper Secondary Female", c = "black",linewidth=3.0)
print(m2*x + b2)

plt.xlabel('Years')
plt.ylabel('No of students')
plt.title('Line plot of Secondary Students vs Year')
plt.legend()

plt.show()
# Out:
# Secondary male m =  6.136363636363925 b= -12158.27272727331
# [145.13636364 151.27272727 157.40909091 163.54545455 169.68181818
#  175.81818182 181.95454545 188.09090909 194.22727273 200.36363636
#  206.5       ]
#
# Secondary female m =  8.500000000000401 b= -16938.545454546263
# [103.95454545 112.45454545 120.95454545 129.45454545 137.95454545
#  146.45454545 154.95454545 163.45454545 171.95454545 180.45454545
#  188.95454545]

# %%
from sklearn.metrics import r2_score 
f1 = [145.13636364, 151.27272727, 157.40909091, 163.54545455, 169.68181818,
 175.81818182, 181.95454545, 188.09090909, 194.22727273, 200.36363636,
 206.5 ]

f2 = [103.95454545, 112.45454545, 120.95454545, 129.45454545, 137.95454545,
 146.45454545, 154.95454545, 163.45454545, 171.95454545, 180.45454545,
 188.95454545]

r2_1 = r2_score(y1, f1 ) 
r2_2 = r2_score(y2, f2 ) 

print('r2 score of linear model wrt Secondary male is      ', r2_1)
print('r2 score of linear model wrt Secondary female is', r2_2)
# Out:
# r2 score of linear model wrt Secondary male is       0.9848795988091739
# r2 score of linear model wrt Secondary female is 0.9935955720228218

# %%
def secondary_male(x):
 y = 6.136363636363925*x -12158.27272727331
 return y

def secondary_female(x):
 y = 8.500000000000401*x -16938.545454546263
 return y

print('secondary male 2016 pred',secondary_male(2016))
print('secondary female 2016 pred',secondary_female(2016))
print('secondary total 2016 pred',secondary_male(2016)+secondary_female(2016),'\n')

print('secondary male 2017 pred',secondary_male(2017))
print('secondary female 2017 pred',secondary_female(2017))
print('secondary total 2017 pred',secondary_male(2017)+secondary_female(2017),'\n')
# Out:
# secondary male 2016 pred 212.63636363636397
# secondary female 2016 pred 197.45454545454413
# secondary total 2016 pred 410.0909090909081
#
# secondary male 2017 pred 218.77272727272793
# secondary female 2017 pred 205.95454545454777
# secondary total 2017 pred 424.7272727272757
