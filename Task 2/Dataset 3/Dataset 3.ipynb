# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/DEEPANSH/Desktop/analytics project/Dataset 3/Dataset3.csv")
df.set_index(['Year'] , inplace = True)
df
# Out:
#       Primary [I - V]  Upper Primary [VI - VIII]  Elementary [I - VIII]  \
# Year
# 1950             0.41                       0.22                   0.38
# 1960             0.50                       0.34                   0.47
# 1970             0.63                       0.45                   0.59
# 1980             0.67                       0.53                   0.63
# 1990             0.75                       0.61                   0.71
# 2000             0.82                       0.75                   0.80
# 2005             0.94                       0.88                   0.92
# 2006             0.94                       0.90                   0.93
# 2007             0.98                       0.91                   0.96
# 2008             0.99                       0.93                   0.97
# 2009             1.00                       0.94                   0.98
# 2010             1.01                       0.95                   0.99
# ...

# %%
df.describe()
# Out:
#        Primary [I - V]  Upper Primary [VI - VIII]  Elementary [I - VIII]  \
# count        17.000000                  17.000000              17.000000
# mean          0.868235                   0.807059               0.852941
# std           0.202276                   0.276106               0.216297
# min           0.410000                   0.220000               0.380000
# 25%           0.750000                   0.610000               0.710000
# 50%           0.980000                   0.910000               0.960000
# 75%           1.010000                   0.990000               1.000000
# max           1.030000                   1.100000               1.050000
#
#        Secondary [IX-X]  Senior Secondary [XI - XII]  High School [IX - XII]  \
# count         11.000000                    11.000000               11.000000
# mean           0.909091                     0.899091                0.910909
# std            0.079430                     0.072174                0.081787
# ...

# %%
df1 = df[['Primary [I - V]','Upper Primary [VI - VIII]','Elementary [I - VIII]']]
df1
# Out:
#       Primary [I - V]  Upper Primary [VI - VIII]  Elementary [I - VIII]
# Year
# 1950             0.41                       0.22                   0.38
# 1960             0.50                       0.34                   0.47
# 1970             0.63                       0.45                   0.59
# 1980             0.67                       0.53                   0.63
# 1990             0.75                       0.61                   0.71
# 2000             0.82                       0.75                   0.80
# 2005             0.94                       0.88                   0.92
# 2006             0.94                       0.90                   0.93
# 2007             0.98                       0.91                   0.96
# 2008             0.99                       0.93                   0.97
# 2009             1.00                       0.94                   0.98
# 2010             1.01                       0.95                   0.99
# ...

# %%
plt.figure(figsize=[9, 4])
x = [1950,1960,1970,1980,1990,2000,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
y1 = [0.41, 0.5 , 0.63, 0.67, 0.75, 0.82, 0.94, 0.94, 0.98, 0.99, 1.  ,
       1.01, 1.01, 1.02, 1.03, 1.03, 1.03]
y2 =[0.22, 0.34, 0.45, 0.53, 0.61, 0.75, 0.88, 0.9 , 0.91, 0.93, 0.94,
       0.95, 0.99, 1.05, 1.08, 1.09, 1.1 ]
y3 = [0.38, 0.47, 0.59, 0.63, 0.71, 0.8 , 0.92, 0.93, 0.96, 0.97, 0.98,
       0.99, 1.  , 1.03, 1.04, 1.05, 1.05]

plt.plot(x, y1, label = "Primary [I - V]",linestyle='--', marker='o', c = "r")
plt.plot(x, y2, label = "Upper Primary [VI - VIII]",linestyle='--', marker='o', c = "b")
plt.plot(x, y3, label = "Elementary [I - VIII]",linestyle='--', marker='o', c = "black")
plt.xlabel('Years')
plt.ylabel('Gender Parity Index')
plt.title('Line plot of GPI vs Year for Junior students')
plt.legend()

plt.show()

# %%
df1.corr()
# Out:
#                            Primary [I - V]  Upper Primary [VI - VIII]  \
# Primary [I - V]                   1.000000                   0.988495
# Upper Primary [VI - VIII]         0.988495                   1.000000
# Elementary [I - VIII]             0.997802                   0.996034
#
#                            Elementary [I - VIII]
# Primary [I - V]                         0.997802
# Upper Primary [VI - VIII]               0.996034
# Elementary [I - VIII]                   1.000000

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

x=df[['Primary [I - V]','Upper Primary [VI - VIII]']]
y=df[['Elementary [I - VIII]']]

linreg = LinearRegression()
A=linreg.fit(x,y)

y_pred=linreg.predict(x)

print(A.coef_)
print(A.intercept_,'\n')

print("The equation of line is (Elementary) = 0.61822335*(Primary) + 0.33257809*(Upper Primary)+ 0.04776776\n")
from sklearn.metrics import r2_score 
r2 = r2_score(y, y_pred ) 
print('r2 score for linear model of primary Students is      ', r2)
# Out:
# [[0.61822335 0.33257809]]
# [0.04776776]
#
# The equation of line is (Elementary) = 0.61822335*(Primary) + 0.33257809*(Upper Primary)+ 0.04776776
#
# r2 score for linear model of primary Students is       0.9997314983935948

# %%
plt.figure(figsize=[9, 4])
x = np.array([1950,1960,1970,1980,1990,2000,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])
y1 = np.array([0.41, 0.5 , 0.63, 0.67, 0.75, 0.82, 0.94, 0.94, 0.98, 0.99, 1.  ,
       1.01, 1.01, 1.02, 1.03, 1.03, 1.03])
y2 =np.array([0.22, 0.34, 0.45, 0.53, 0.61, 0.75, 0.88, 0.9 , 0.91, 0.93, 0.94,
       0.95, 0.99, 1.05, 1.08, 1.09, 1.1 ])
y3 = np.array([0.38, 0.47, 0.59, 0.63, 0.71, 0.8 , 0.92, 0.93, 0.96, 0.97, 0.98,
       0.99, 1.  , 1.03, 1.04, 1.05, 1.05])
x4 = np.array([1950,1960,1970,1980,1990,2000,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,1950,1960,1970,1980,1990,2000,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])
y4 = np.array([0.41, 0.5 , 0.63, 0.67, 0.75, 0.82, 0.94, 0.94, 0.98, 0.99, 1.  ,
       1.01, 1.01, 1.02, 1.03, 1.03, 1.03,0.22, 0.34, 0.45, 0.53, 0.61, 0.75, 0.88, 0.9 , 0.91, 0.93, 0.94,
       0.95, 0.99, 1.05, 1.08, 1.09, 1.1])

plt.scatter(x, y1, label = "Primary [I - V]", c = "r")
plt.scatter(x, y2, label = "Upper Primary [VI - VIII]", c = "b")
plt.scatter(x, y3, label = "Elementary [I - VIII]", c = "g")

m, b = np.polyfit(x4, y4, 1)

plt.plot(x4, m*x4 + b,label = "Reg line Elementary", c = "black",linewidth=3.0)

plt.xlabel('Years')
plt.ylabel('Gender Parity Index')
plt.title('Line plot of GPI vs Year for students')
plt.legend()

plt.show()

# %%
from sklearn.metrics import r2_score 
f1 = [0.28453321, 0.40061883, 0.51670445, 0.63279008, 0.7488757,  0.86496132,
 0.92300413, 0.9346127,  0.94622126, 0.95782982, 0.96943838, 0.98104695,
 0.99265551, 1.00426407, 1.01587263, 1.02748119, 1.03908976]
f2 = [ 0.28453321,
 0.40061883, 0.51670445, 0.63279008, 0.7488757,  0.86496132, 0.92300413,
 0.9346127,  0.94622126, 0.95782982, 0.96943838, 0.98104695, 0.99265551,
 1.00426407, 1.01587263, 1.02748119, 1.03908976]
r2_1 = r2_score(y1, f1 ) 
r2_2 = r2_score(y2, f2 ) 

print('r2 score of linear model wrt primary Students is      ', r2_1)
print('r2 score of linear model wrt upper primary Students is', r2_2)
# Out:
# r2 score of linear model wrt primary Students is       0.9282592421667263
# r2 score of linear model wrt upper primary Students is 0.9375683106450436

# %%
df2 = df[['Secondary [IX-X]','Senior Secondary [XI - XII]','High School [IX - XII]']]
df2_new=df2.dropna()
df2_new
# Out:
#       Secondary [IX-X]  Senior Secondary [XI - XII]  High School [IX - XII]
# Year
# 2005              0.80                         0.80                    0.80
# 2006              0.81                         0.83                    0.82
# 2007              0.85                         0.84                    0.85
# 2008              0.86                         0.85                    0.85
# 2009              0.88                         0.87                    0.88
# 2010              0.88                         0.86                    0.87
# 2011              0.93                         0.92                    0.93
# 2012              0.96                         0.94                    0.99
# 2013              1.00                         0.98                    1.00
# 2014              1.01                         0.99                    1.01
# 2015              1.02                         1.01                    1.02

# %%
plt.figure(figsize=[9, 4])
x = [2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
y1 = [0.8 , 0.81, 0.85, 0.86, 0.88, 0.88, 0.93, 0.96, 1.  , 1.01, 1.02]
y2 = [0.8 , 0.83, 0.84, 0.85, 0.87, 0.86, 0.92, 0.94, 0.98, 0.99, 1.01] 
y3 = [0.8 , 0.82, 0.85, 0.85, 0.88, 0.87, 0.93, 0.99, 1.  , 1.01, 1.02]

plt.plot(x, y1, label = "Secondary [IX-X]",linestyle='--', marker='o', c = "r")
plt.plot(x, y2, label = "Senior Secondary [XI - XII]",linestyle='--', marker='o', c = "b")
plt.plot(x, y3, label = "High School [IX - XII]",linestyle='--', marker='o', c = "black")
plt.xlabel('Years')
plt.ylabel('Gender Parity Index')
plt.title('Line plot of GPI vs Year for Senior students')
plt.legend()

plt.show()

# %%
df2_new.corr()
# Out:
#                              Secondary [IX-X]  Senior Secondary [XI - XII]  \
# Secondary [IX-X]                     1.000000                     0.992381
# Senior Secondary [XI - XII]          0.992381                     1.000000
# High School [IX - XII]               0.991471                     0.987806
#
#                              High School [IX - XII]
# Secondary [IX-X]                           0.991471
# Senior Secondary [XI - XII]                0.987806
# High School [IX - XII]                     1.000000

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

x=df2_new[['Secondary [IX-X]','Senior Secondary [XI - XII]']]
y=df2_new[['High School [IX - XII]']]

linreg = LinearRegression()
A=linreg.fit(x,y)

y_pred=linreg.predict(x)

print(A.coef_)
print(A.intercept_,'\n')

print("The equation of line is (High School) = 0.75912967*(Primary) + 0.29029084*(Upper Primary) - 0.04020665\n")
from sklearn.metrics import r2_score 
r2 = r2_score(y, y_pred ) 
print('r2 score for linear model of primary Students is      ', r2)
# Out:
# [[0.75912967 0.29029084]]
# [-0.04020665]
#
# The equation of line is (High School) = 0.75912967*(Primary) + 0.29029084*(Upper Primary) - 0.04020665
#
# r2 score for linear model of primary Students is       0.9840118474326096

# %%
plt.figure(figsize=[9, 4])
x = np.array([2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])
y1 = np.array([0.8 , 0.81, 0.85, 0.86, 0.88, 0.88, 0.93, 0.96, 1.  , 1.01, 1.02])
y2 = np.array([0.8 , 0.83, 0.84, 0.85, 0.87, 0.86, 0.92, 0.94, 0.98, 0.99, 1.01])
y3 = np.array([0.8 , 0.82, 0.85, 0.85, 0.88, 0.87, 0.93, 0.99, 1.  , 1.01, 1.02])

x4 = np.array([2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])
y4 = np.array([0.8 , 0.81, 0.85, 0.86, 0.88, 0.88, 0.93, 0.96, 1.  , 1.01, 1.02,0.8 , 0.82, 0.85, 0.85, 0.88, 0.87, 0.93, 0.99, 1.  , 1.01, 1.02])

plt.scatter(x, y1, label = "Secondary [IX-X]", c = "r")
plt.scatter(x, y2, label = "Senior Secondary [XI - XII]", c = "b" )
plt.scatter(x, y3, label = "High School [IX - XII]']]", c = "g")

m, b = np.polyfit(x4, y4, 1)

plt.plot(x4, m*x4 + b,label = "Reg line High School", c = "black",linewidth=3.0)

plt.xlabel('Years')
plt.ylabel('Gender Parity Index')
plt.title('Line plot of GPI vs Year for Senior students')
plt.legend()

plt.show()

# %%
from sklearn.metrics import r2_score 
f1 = [0.79090909, 0.81472727, 0.83854545, 0.86236364, 0.88618182, 0.91,
 0.93381818, 0.95763636, 0.98145455, 1.00527273, 1.02909091]
f2 = [ 0.79090909, 0.81472727, 0.83854545, 0.86236364, 0.88618182, 0.91,
 0.93381818, 0.95763636, 0.98145455, 1.00527273, 1.02909091]
r2_1 = r2_score(y1, f1 ) 
r2_2 = r2_score(y2, f2 ) 

print('r2 score of linear model wrt Secondary Students is      ', r2_1)
print('r2 score of linear model wrt Senior Secondary Students is', r2_2)
# Out:
# r2 score of linear model wrt Secondary Students is       0.973861672103745
# r2 score of linear model wrt Senior Secondary Students is 0.9167888265968568

# %%
df3 = df[['Higher Education']]
df3_n=df3.dropna()
df3_n
# Out:
#       Higher Education
# Year
# 2005              0.69
# 2006              0.69
# 2007              0.70
# 2008              0.72
# 2009              0.74
# 2010              0.86
# 2011              0.88
# 2012              0.89
# 2013              0.92
# 2014              0.92
# 2015              0.92

# %%
plt.figure(figsize=[9, 4])
x = [2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015]
y = [[0.69],[0.69],[0.7 ],[0.72],[0.74],[0.86],[0.88],[0.89],[0.92],[0.92],[0.92]]

plt.plot(x, y, label = "Higher Education",linestyle='--', marker='o', c = "b")

plt.xlabel('Years')
plt.ylabel('Gender Parity Index')
plt.title('Line plot of GPI vs Year for College students')
plt.legend()

plt.show()

# %%
plt.figure(figsize=[9, 4])
x = np.array([2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])
y = np.array([[0.69],[0.69],[0.7 ],[0.72],[0.74],[0.86],[0.88],[0.89],[0.92],[0.92],[0.92]])

plt.scatter(x, y, label = "Higher Education", c = "b")

m, b = np.polyfit(x, y, 1)

plt.plot(x, m*x + b,label = "Reg line Higher Education", c = "black",linewidth=3.0)

plt.xlabel('Years')
plt.ylabel('Gender Parity Index')
plt.title('Line plot of GPI vs Year for College students')
plt.legend()

plt.show()

# %%
from sklearn.metrics import r2_score 
f1 = [0.66590909, 0.69509091, 0.72427273, 0.75345455, 0.78263636, 0.81181818,
 0.841,      0.87018182, 0.89936364, 0.92854545, 0.95772727]
r2_ = r2_score(y, f1 ) 

print('r2 score of linear model is      ', r2_)
# Out:
# r2 score of linear model is       0.901023086446309

# %%
df.loc['2009':]
# Out:
#       Primary [I - V]  Upper Primary [VI - VIII]  Elementary [I - VIII]  \
# Year
# 2009             1.00                       0.94                   0.98
# 2010             1.01                       0.95                   0.99
# 2011             1.01                       0.99                   1.00
# 2012             1.02                       1.05                   1.03
# 2013             1.03                       1.08                   1.04
# 2014             1.03                       1.09                   1.05
# 2015             1.03                       1.10                   1.05
#
#       Secondary [IX-X]  Senior Secondary [XI - XII]  High School [IX - XII]  \
# Year
# 2009              0.88                         0.87                    0.88
# 2010              0.88                         0.86                    0.87
# 2011              0.93                         0.92                    0.93
# ...

# %%
data = df.loc['2009':]
levels=['2009','2010','2011','2012','2013','2014', '2015']

primary= data.iloc[:, 0].values.reshape(-1, 1)
primary=np.concatenate((primary,[primary[0]]))

upper_primary= data.iloc[:, 1].values.reshape(-1, 1)
upper_primary=np.concatenate((upper_primary,[upper_primary[0]]))

elementary= data.iloc[:, 2].values.reshape(-1, 1)
elementary=np.concatenate((elementary,[elementary[0]]))

secondary= data.iloc[:, 3].values.reshape(-1, 1)
secondary=np.concatenate((secondary,[secondary[0]]))

senior_secondary= data.iloc[:, 4].values.reshape(-1, 1)
senior_secondary=np.concatenate((senior_secondary,[senior_secondary[0]]))

high_school= data.iloc[:, 5].values.reshape(-1, 1)
high_school=np.concatenate((high_school,[high_school[0]]))

higher_education= data.iloc[:, 6].values.reshape(-1, 1)
higher_education=np.concatenate((higher_education,[higher_education[0]]))

# %%
label=np.linspace(0, 2*np.pi, num=len(primary))

# %%
plt.figure(figsize=(10,10))
plt.subplot(polar=True)

plt.plot(label,primary,c = "r", marker='o')
#plt.fill(label,primary,c = "r",alpha=0.1)

plt.plot(label,upper_primary,c = "g", marker='o')
#plt.fill(label,upper_primary,c = "g",alpha=0.1)

plt.plot(label,elementary,c = "b", marker='o')
#plt.fill(label,elementary,c = "b",alpha=0.1)

plt.plot(label,secondary,c = "y", marker='o')
#plt.fill(label,secondary,c = "y",alpha=0.1)

plt.plot(label,senior_secondary,c = "black", marker='o')
#plt.fill(label,senior_secondary,c = "black",alpha=0.1)

plt.plot(label,high_school,c = "c", marker='o')
#plt.fill(label,IX_XII,c = "c",alpha=0.1)

plt.plot(label,higher_education,c = "m", marker='o')
#plt.fill(label,higher_education,c = "m",alpha=0.1)

lines,labels=plt.thetagrids(np.degrees([0., 0.8975979 , 1.7951958 , 2.6927937 , 3.5903916 ,4.48798951, 5.38558741]), labels=['2009','2010','2011','2012','2013','2014', '2015'])
plt.title('GPI Score Radar Chart', y=1.05,fontdict={'fontsize':18})
plt.legend(labels=['primary','upper_primary','elementary','secondary','senior_secondary','high_school','higher_education'])
plt.show()
